# %% [markdown]
# # Review - Week 07

# %% [markdown]
# ## General

# %% [markdown]
# ### `still kinda struggling with for loops and lists and strings`
# ### `none..... im struggling....`
# ### `2 star movies qns ... im still lost`
# - Please come for consultation, don't suffer in silence.
# - Consultation slots will still be open during Recess Week.
# - **Mandatory consultation based on Quiz 3 scores - will be informed via email.**

# %% [markdown]
# ### `little challenging to apply the concepts taught into real-workd scenarios. it was also a little challenging to try to finish everything on time.`
# - Practice (thoughtfully)!
#     - How to identify what the question wants?
#     - Memorize common [programming idioms](https://en.wikipedia.org/wiki/Programming_idiom)
#         - [Use](http://courses.cms.caltech.edu/cs11/material/python/misc/python_idioms.html) [online](https://en.wikibooks.org/wiki/Python_Programming/Idioms) [resources](https://betterprogramming.pub/10-tiny-python-idioms-for-collections-and-data-structures-2f0d2923832)!
#         - Also, try to identify common idioms in your exercise / lab / quiz solutions!

# %% [markdown]
# ### `suggestions for the quiz, it would be good if a printout of the question can be given to us, so that we can work on it directly instead of having to copy down the question before tackling it`
# - Sure

# %% [markdown]
# ### `memory state diagram thing just confuses us more than it helps with our thinking. I appreciate knowing more about it, but maybe (since it's not tested) we don't spend so much time on this thing`
# - Memory State Diagrams (MSDs) is not tested in the sense that you will not be asked to draw a MSD in the finals
# - However, it is a tool for you to understand what is happening in the code (i.e., code tracing), especially when iterating through lists
# - Also, part of your Week 1 Learning Outcomes:
#
# ![image.png](attachment:611c149d-363a-4bbb-a384-3b9660234bb9.png)

# %% [markdown]
# ### `try on more complicated for-loops and string slicing types of question`
# - Sample exams will be released soon
# - Come talk to me if you want harder questions

# %% [markdown]
# ## Week 6 ICE

# %% [markdown]
# ### `(name, genre, duration) = movie is it possible to define them one by one instead? eg name = movie[0], genre = movie[1]`
# - Yes! These are just different ways to do the same thing (extracting the values from the `movie` list)
# - Note that `(name, genre, duration) = movie` will cause an error if `len(movie) != 3`, but `name = movie[0]` will still work

# %% [markdown]
# ### `trial lab qn the steps to finding first index for odd number is still abit confusing`
# - How do you [control code flow](https://docs.python.org/3/tutorial/controlflow.html)? ([Another good resource](https://www.oreilly.com/library/view/python-in-a/0596001886/ch04s09.html))
#     - Tools covered so far: `if/elif/else`, `for-loop`, `function/return`
#     - What is the most appropriate tool here?
